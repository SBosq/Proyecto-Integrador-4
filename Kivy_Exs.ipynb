# %%
from kivy.uix.boxlayout import BoxLayout
from kivy.uix.boxlayout import BoxLayout as BoxLayout2
from kivy.uix.gridlayout import GridLayout
from kivy.uix.anchorlayout import AnchorLayout
from kivy.uix.relativelayout import RelativeLayout
from kivy.app import App
from kivy.uix.button import Button
from kivy.lang import Builder
from kivy.uix.screenmanager import ScreenManager, Screen
from kivy.uix.label import Label
from kivy.uix.scrollview import ScrollView
from kivy.uix.textinput import TextInput
from kivy.uix.spinner import Spinner
from kivy.animation import Animation
from sys import exit

import pymysql

class MainView(ScrollView):
    ac_id = False
    cap_ton = False
    ac_cant = False
    mod_ac = False 
    marca_ac = False
    
    q = """SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.ac_ID DESC
            """
    db = pymysql.connect("localhost","testuser","test123","TESTDB" )
    cursor = db.cursor()
    cursor.execute("SELECT VERSION()")
    
    def add_ac(self, vals):
        alert = 0
        for val in vals:
            if len(val) == 0:
                alert = 1
                break
                
        if alert == 0:
            q = self.query("INSERT INTO 'ac' (cap_Ton, ac_ID, ac_Cant, mod_AC, marca_AC) VALUES ('%d', '%s', '%d', '%s', '%s')"
                          %(int(vals[0]), str(vals[1]), int(vals[2]), str(vals[3]), str(vals[4])))
            self.fill(self.db_data(q))
            self.qchange()
        else:
            pass
        
    def del_ac(self, vals):
        ac_val = False
        i = 0
        for val in vals:
            if len(val) > 0:
                break
            i += 1
        if i == 0:
            q = self.query("DELETE FROM ac WHERE ac_ID = '%s'" %str(vals[i]))
            self.fill(self.db_data(q))
            self.qchange()
        elif i == 1:
            try:
                parts = str(vals[i]).split('\n')
                string = ''
                for items in parts:
                    string += item
                    if len(string) <= 15:
                        ac_val = True
                    else:
                        pass
            except:
                pass
        else:
            pass
        
    def qchange(self):
        if self.ac_id is False: #desc_ID is used in example, however we will use ac_ID
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.ac_ID DESC"""
                          )
            self.ac_id = True
        else:
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.ac_ID ASC"""
                          )
            self.ac_id = False
            
        self.fill(self.db_data(q))
        
    def qchange2(self):
        if self.cap_ton is False: #desc_name is used in example, however we will use cap_ton
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.cap_Ton DESC"""
                          )
            self.cap_ton = True
        else:
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.cap_Ton ASC"""
                          )
            self.cap_ton = False
            
        self.fill(self.db_data(q))
        
    def qchange3(self):
        if self.ac_cant is False: #desc_date is used in example, however we will use ac_cant
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.ac_Cant DESC"""
                          )
            self.ac_cant = True
        else:
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.ac_Cant ASC"""
                          )
            self.ac_cant = False
            
        self.fill(self.db_data(q))
        
    def qchange4(self):
        if self.mod_ac is False: 
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.mod_Ac DESC"""
                          )
            self.mod_ac = True
        else:
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.mod_Ac ASC"""
                          )
            self.mod_ac = False
            
        self.fill(self.db_data(q))
        
    def qchange5(self):
        if self.marca_ac is False: 
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.marca_Ac DESC"""
                          )
            self.marca_ac = True
        else:
            q = self.query("""
            SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
            INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
            INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
            INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
            ORDER BY ac.marca_Ac ASC"""
                          )
            self.marca_ac = False
            
        self.fill(self.db_data(q))
        
    def search_sort(self, value):
        query='''
        SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
        INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
        INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
        INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
        WHERE ac.ac_ID LIKE "''' + str(value) + '0"'
        q = self.query(query)
        
        self.fill(self.db_data(q))
        
    def display_make(self): #display_binary is used in example, however we will use display_make
        query='''
        SELECT ac.cap_Ton, ac.ac_ID, ac.ac_Cant, ac.mod_Ac, ac.marca_Ac FROM ac
        INNER JOIN departamento ON (departamento.ac_ID = ac.ac_ID)
        INNER JOIN mm ON (mm.marca_Ac = ac.marca_Ac)
        INNER JOIN empleado ON (empleado.dep_ID = departamento.dep_ID && departamento.ac_ID = ac.ac_ID)
        WHERE ac.marca_Ac LIKE "''' + str(value)
        q = self.query(query)
        
        self.fill(self.db_data(q))
        
    def query(self, q):
        q = self.q
        return self.q
    
    def db_data(self, query):
        vector = []
        
        self.cursor.execute(query)
        
        result = self.cursor.fetchall()
        
        for row in result:
            string = str(row[0]) + "," + str(row[1]) + "," + str(row[2]) + "," + str(row[3]) + "," + str(row[4])
            vector.append(string)
            
        return vector
    
    def fill(self, strings):
        self.GL.clear_widgets()
        
        for row in strings:
            splitRow = row.split(",")
            for data in splitRow:
                label = Label(text=data, size_hint_y=None, font_size="13sp")
                self.GL.add_widget(label)
                
        self.db.commit()
        
        
    def __init__(self, **kwargs):
        super(MainView, self).__init__(**kwargs)
        
        self.GL = GridLayout(cols=6, spacing=.01, size_hint_y=None)
        self.GL.bind(minimum_height=self.GL.setter('height'))
        self.fill(self.db_data(self.q))
        self.add_widget(self.GL)
        
Builder.load_string("""

<MenuScreen>:
    BoxLayout:
        
        BoxLayout:
            orientation: 'vertical'
            spacing: 10
            
            AnchorLayout:
                anchor_x: 'center'
                anchor_y: 'bottom'
                
                Button:
                    size_hint: 0.5, 0.2
                    text: "Log In"
                    on_press:
                        root.manager.transition.direction = "up"
                        root.manager.current = 'login'
                        
            AnchorLayout:
                anchor_x: 'center'
                anchor_y: 'top'
                
                Button:
                    size_hint: 0.5, 0.2
                    text: "Quit"
                    on_press:
                        app.get_running_app().stop()
        Image:
            source: 'mini_split.png'
            
<SettingsScreen>:

<ForPeople>:

""")

class LogPage(AnchorLayout):
    
    def callback_goto(self, instance):
        if self.name_prompt.text == "Admin" and self.pwd_prompt.text == "Carlota1942":
            sm.transition.direction = 'up'
            sm.current = 'settings'
        elif self.name_prompt.text == "empleado" and self.pwd_prompt.text == "UM1942":
            sm.transition.direction = 'left'
            sm.current = 'mortals'
        else:
            pass
        self.name_prompt.text = ""
        self.pwd_prompt.text = ""
        
    def __init__(self, **kwargs):
        super(LogPage, self).__init__(**kwargs)
        self.anchor_x = 'center'
        self.anchor_y = 'center'
        
        centralBox = BoxLayout(spacing=2)
        centralBox.size_hint = (0.4, 0.2)
        centralBox.orientation = 'vertical'
        #innerAnchor.add_widget(log_btn)
        
        #innerBox2.add_widget(pwd)
        #innerBox2.add_widget(self.pwd_prompt)
        
        centralBox.add_widget(innerBox1)
        centralBox.add_widget(innerBox2)
        centralBox.add_widget(innerAnchor)
        self.add_widget(centralBox)
        
class MenuScreen(Screen):
    pass

class SettingsScreen(Screen):
    pass

class LoginScreen(Screen):
    pass

class ForPeople(Screen):
    pass

ls = LoginScreen(name='login')
ss = SettingsScreen(name='settings')
fp = ForPeople(name="mortals")

#LP = LogPage()
layout = BoxLayout(orientation='vertical')
layout2 = BoxLayout2(orientation='vertical')
BL = BoxLayout()
BL2 = BoxLayout()
UpperLayer = BoxLayout(spacing=5)
UpperLayer2 = BoxLayout(spacing=5)
LabelLayout = BoxLayout()
LabelLayout2 = BoxLayout()

LabelLayout.size_hint_y = .4
LabelLayout2.size_hint_y = .4

RL = RelativeLayout()
RL2 = RelativeLayout()

UpperLayer.add_widget(RL)
UpperLayer2.add_widget(RL2)

layout.add_widget(UpperLayer)
layout2.add_widget(UpperLayer2)

layout.add_widget(LabelLayout)
layout2.add_widget(LabelLayout2)

#MV = MainView()
MV2 = MainView()

#MV.size_hint_y = 1.7
MV2.size_hint_y = 1.7

def callback(instance):
    sm.transition.direction = 'down'
    sm.current = 'menu'
def callback2(instance, value):
    #MV.qchange()
    MV2.qchange()
def callback3(instance, value):
    #MV.qchange2()
    MV2.qchange2()
def callback4(instance, value):
    #MV.qchange3()
    MV2.qchange3()
def on_enter(instance, value):
    if instance != txt: 
        if value != '':
            MV2.search_sort(value=value)
        else:
            MV2.qchange()
            
#def on_enter_make(instance, value):
 #   if instance.text not string:
  #      instance.text = ""

def get_values(instance):
    values = [txt2.text, txt3.text, txt4.text, txt5.text, txt6.text]
    if not spinner.text == "Delete":
        MV.add_record(values)
    else:
        MV.del_record(values)
    txt2.text = ""
    txt3.text = ""
    txt4.text = ""
    txt5.text = ""
    txt6.text = ""
    
def del_mode(instance, value):
    if spinner.text == "Delete":
        if txt3.text != "":
            txt2.disabled = True
        elif txt2.text != "":
            txt3.disabled = True
        else:
            txt2.disabled = False
            txt3.disabled = False
            
def make_model(instance):
    MV2.display_make()
    
#layout.add_widget(MV)
layout2.add_widget(MV2)

layout.add_widget(BL)
layout.add_widget(BL2)

btn = Button(text="Back to Menu")
btn2 = Button(text="Back to Menu")

btn.bind(on_press=callback)
btn2.bind(on_press=callback)
btn.size_hint = (1, 0.3)
btn2.size_hint = (1, 0.3)

BL.add_widget(btn)
BL2.add_widget(btn2)

txt = TextInput(multiline=False)
txt.size_hint = (0.5, 0.33)
txt.bind(text=on_enter)
txt.pos=[UpperLayer.width/0.5, 75]
RL.add_widget(txt)

txt_clone = TextInput(multiline=False)
txt_clone.size_hint = (0.5, 0.33)
txt_clone.bind(text=on_enter)
txt_clone.pos=[UpperLayer.width/0.5, 75]
RL2.add_widget(txt_clone)

txt2 = TextInput(multiline=False)
txt2.size_hint = (0.19, 0.2)
txt2.pos = [-500, 20]
txt2.bind(text=del_mode)
RL.add_widget(txt2)

txt3 = TextInput(multiline=False)
txt3.size_hint = (0.19, 0.2)
txt3.pos = [-500, 20]
txt3.bind(text=del_mode)
RL.add_widget(txt3)

txt4 = TextInput(multiline=False)
txt4.size_hint = (0.19, 0.2)
txt4.pos = [1500, 20]
#txt4.bind(text=make_model)
RL.add_widget(txt4)

txt5 = TextInput(multiline=False)
txt5.size_hint = (0.19, 0.2)
txt5.pos = [1500, 20]
#txt5.bind(text=make_model)
RL.add_widget(txt5)

txt6 = TextInput(multiline=False)
txt6.size_hint = (0.19, 0.2)
txt6.pos = [1500, 20]
txt6.bind(text=del_mode)
RL.add_widget(txt6)

add_btn = Button(text="Add AC")
add_btn.pos = [-500, 20]
add_btn.size_hint = (0.17, 0.2)
add_btn.bind(on_press=get_values)
RL.add_widget(add_btn)

del_btn = Button(text="Delete AC")
del_btn.pos = [-500, 20]
del_btn.size_hint = (0.17, 0.2)
del_btn.bind(on_press=get_values)
RL.add_widget(del_btn)

spinner = Spinner(
    text = 'Tools',
    values = ['Search by AC ID', 'Add AC', 'Delete AC', 'AC make/model'],
    size_hint=(None, None),
    size=(200, 50),
    pos_hint={'x': .5, 'y': .5}
)
#spinner_btn.size_hint = (None, None)
#spinner_btn.size = (200, 50)
#spinner_btn.pos_hint = {"x":.5, "y":.5}
#spinner_btn.bind(on_press=make)

def clear_fields():
    txt.text = ""
    txt2.text = ""
    txt3.text = ""
    txt4.text = ""
    txt5.text = ""
    txt6.text = ""
    
    
def show_selected_value(spinner, text):
    if text == 'Add AC':
        clear_fields()
        txt2.disabled = False
        txt3.disabled = False
        
        anim = Animation(x=-800)
        anim.start(txt)
        
        anim = Animation(x=UpperLayer.width/5.5)
        anim.start(txt2)
        
        anim = Animation(x=UpperLayer.width/2.9)
        anim.start(txt3)
        
        anim = Animation(x=UpperLayer.width/1.97)
        anim.start(txt4)
        
        anim = Animation(x=UpperLayer.width/1.49)
        anim.start(txt5)
        
        anim = Animation(x=UpperLayer.width/1.2)
        anim.start(txt6)
        
        anim = Animation(x=-500)
        anim.start(del_btn)
        
        anim = Animation(x=UpperLayer.width/70)
        anim.start(add.btn)
        
    if spinner.txt == "Delete AC":
        clear_fields()
        txt.text = ""
        anim = Animation(x=-500)
        anim.start(add_btn)
        anim.start(txt)
        anim = Animation(x=1500)
        anim.start(txt4)
        anim.start(txt5)
        anim.start(txt6)
        
        anim = Animation(x=UpperLayer.width / 5.5)
        anim.start(txt2)
        anim = Animation(x=UpperLayer.width / 2.9)
        anim.start(txt3)
        
        anim = Animation(x=UpperLayer.width/70)
        anim.start(del_btn)
        
    if text == "AC ID":
        anim = Animation(x=-800)
        anim.start(txt3)
        anim.start(txt2)
        anim.start(add_btn)
        anim.start(del_btn)
        anim = Animation(x=1500)
        anim.start(txt4)
        anim.start(txt5)
        anim.start(txt6)
        
        anim = Animation(x=200)
        anim.start(txt)
        
spinner.bind(text=show_selected_value)
#spinner_btn.bind(text=show_selected_value)

UpperLayer.add_widget(spinner)
#UpperLayer2.add_widget(spinner_btn)

labels = ['cap_Ton', 'AC_ID', 'AC_Cant', 'mod_AC', 'marca_AC']
for label in labels:
    text = '[ref='+label.lower()+']'+label+'[/ref]'
    widget = Label(text= text, markup=True)
    widget.size_hint_y=0.08
    if label == 'cap_Ton':
        widget.bind(on_ref_press=callback2)
    elif label == 'AC_ID':
        widget.bind(on_ref_press=callback3)
    elif label == 'AC_Cant':
        widget.bind(on_ref_press=callback4)
    LabelLayout.add_widget(widget)
    
for label in labels:
    text = '[ref='+label.lower()+']'+label+'[/ref]'
    widget2 = Label(text= text, markup=True)
    widget2.size_hint_y=0.08
    if label == 'cap_Ton':
        widget2.bind(on_ref_press=callback2)
    elif label == 'AC_ID':
        widget2.bind(on_ref_press=callback3)
    elif label == 'AC_Cant':
        widget2.bind(on_ref_press=callback4)
    LabelLayout.add_widget(widget2)
    
ss.add_widget(layout)

sm = ScreenManager()
sm.add_widget(MenuScreen(name='menu'))
sm.add_widget(ss)
sm.add_widget(fp)
sm.add_widget(ls)

class MyApp(App):
    def build(self):
        return sm
    
if __name__ == '__main__':
    MyApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\saulo\.kivy\logs\kivy_20-05-17_32.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.1.12
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.1.23
# [INFO   ] [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "C:\Users\saulo\Anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\saulo\Anaconda3\python.exe"
# [INFO   ] [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# ...
